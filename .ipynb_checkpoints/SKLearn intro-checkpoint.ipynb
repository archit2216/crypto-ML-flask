# %% [raw]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import pandas_datareader as web
# import tensorflow
# import sklearn
# import datetime as dt
#
# from sklearn.preprocessing import MinMaxScaler
# from tensorflow.keras.layers import Dense,Dropout,LSTM
# from tensorflow.keras.models import Sequential
#
# crypto_currency='BTC'
# against_currency='USD'
#
# start=dt.datetime(2017,1,1)
# end=dt.datetime.now()
#
# total_data=web.DataReader("Downloads\convertcsv.csv")
#
# total_data.head()

# %%
from sklearn import datasets
import pandas as pd
boston=datasets.load_boston()
type(boston)
X=boston.data
Y=boston.target
# Out:
# E:\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
df=pd.DataFrame(X)
print(boston.feature_names)
df.columns=boston.feature_names
df.describe()
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# ...

# %%
boston.DESCR
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
from sklearn import model_selection
X_train,X_test,Y_train,Y_test=model_selection.train_test_split(X,Y)  #this split will give us 4 array=> Xtrain,Xtest,Ytrain,Ytest
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (379, 13)
# (127, 13)
# (379,)
# (127,)

# %%
#importing algo to our code
from sklearn.linear_model import LinearRegression
alg1=LinearRegression()

# %%
alg1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_predicted=alg1.predict(X_test)
Y_predicted

train_score1=alg1.score(X_train,Y_train)
test_score1=alg1.score(X_test,Y_test)
#compare predicted and actual values, you can plot them

# %%
import matplotlib.pyplot as plt

plt.scatter(Y_predicted,Y_test)
plt.axis([0,40,0,40])
plt.show()

# %%
#Diabetes dataset
from sklearn import datasets
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
Diabetes=datasets.load_diabetes()
x=Diabetes.data
y=Diabetes.target
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y)
# print(x_train.shape)
# print(x_test.shape)
# print(y_train.shape)
# print(y_test.shape)
algo=LinearRegression()
algo.fit(x_train,y_train)
y_pred=algo.predict(x_test)

plt.plot(y_test,color="blue",label="Actual Data")
plt.plot(y_pred,color="red",label="Predicted Data")
plt.legend(loc="lower center")
plt.axis([40,100,40,100])
plt.show()

# %%
#Iris dataSet
from sklearn import datasets
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
Iris=datasets.load_iris()
x=Iris.data
y=Iris.target
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y)
Algorithm=LinearRegression()
Algorithm.fit(x_train,y_train)
m=Algorithm.coef_
c=Algorithm.intercept_
Y_calc=m*x_test+c;
u=((y_test-Y_calc)**2).sum()
v=((y_test-y_test.mean())**2).sum()
COD=1-u/v
print(COD)
y_pred=Algorithm.predict(x_test)

plt.plot(y_pred,color="red",label="Predicted Data")
plt.plot(y_test,color="blue",label="Actual Data")
plt.legend(loc="upper left")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 15>()
#      13 c=Algorithm.intercept_
#      14 Y_calc=m*x_test+c;
# ---> 15 u=((y_test-Y_calc)**2).sum()
#      16 v=((y_test-y_test.mean())**2).sum()
#      17 COD=1-u/v
#
# ValueError: operands could not be broadcast together with shapes (38,) (38,4)

# %%
from sklearn import datasets
import pandas as pd
from sklearn import model_selection
boston=datasets.load_boston()

x2=boston.data
y2=boston.target
DF=pd.DataFrame(x2)
DF.columns=boston.feature_names
DF.describe()
# Out:
# E:\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
# for names in DF:
# #     print(names)
#     DF[names,"_",names]=names
from sklearn.linear_model import LinearRegression
DF["age_age"]=DF.AGE**2
DF.describe()
x2=DF.values
x2_train,x2_test,y2_train,y2_test=model_selection.train_test_split(x2,y2,random_state=0)

algo2=LinearRegression()
algo2.fit(x2_train,y2_train)


y2_pred=algo2.predict(x2_test)

train_score2=algo2.score(x2_train,y2_train)
test_score2=algo2.score(x2_test,y2_test)
print(train_score2," ",test_score2)
print(train_score1," ",test_score1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 5>()
#       1 # for names in DF:
#       2 # #     print(names)
#       3 #     DF[names,"_",names]=names
#       4 from sklearn.linear_model import LinearRegression
# ----> 5 DF["age_age"]=DF.AGE**2
#       6 DF.describe()
#       7 x2=DF.values
#
# NameError: name 'DF' is not defined

# %%
import numpy as np
import sklearn 
import pandas as pd
import pandas_datareader as web
import datetime as dt
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
crypto_currency='BTC'
against_currency='USD'

start=dt.datetime(2017,1,1)
end=dt.datetime(2021,12,31)

data=web.DataReader(f'{crypto_currency}-{against_currency}','yahoo',start,end)

x_train=data[['Open','High','Low','Volume']].values
y_train=data['Close'].values

test_start=dt.datetime(2022,1,1)
test_end=dt.datetime.now()

test_data=web.DataReader(f'{crypto_currency}-{against_currency}','yahoo',test_start,test_end)
x_test=test_data[['Open','High','Low','Volume']].values
y_test=test_data['Close'].values


ALGORITHM=LinearRegression()
ALGORITHM.fit(x_train,y_train)

y_pred=ALGORITHM.predict(x_test)

# dframe=pd.DataFrame(y_test,y_pred)
# dfr=pd.DataFrame({'Actual Closing Price':y_test,'Predicted Closing Price':y_pred})
# print(dfr.head(25))
# train_score=ALGORITHM.score(x_train,y_train)
# test_score=ALGORITHM.score(x_test,y_test)
# print(train_score," ",test_score)
# # plt.plot(y_pred,color="red",label="Predicted")
# # plt.plot(y_test,color="blue",label="Actual")
# # plt.legend(loc="upper left")
# # plt.show()
# graph=dfr.head(25)
# graph.plot(kind="bar")

# %%
import pickle
pickle.dump(ALGORITHM,open('lr_model.pkl','wb'))
